# %% [markdown]
# Bài 1:Nhập vào số nguyên n. In ra màn hình số gấp đôi n

# %%
n=int(input())
print(n*2)
# Out:
# 0

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a=float(input())
b=float(input())
if a>b:
    r=b/2
    s=(r**2)*3.14
    print(f"{(a*b-s):.2f}")
else:
    r=a/2
    s=(r**2)*3.14
    print(f"{(a*b-s):.2f}")
# Out:
# 10.32

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
c=str(input())
n=ord(c)
if n in range(97,122):
    print(c.upper())
else:
    print(c.lower())
# Out:
# H

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
c=input()
if len(c)==1:
    if c.isalpha():
        print(c,'là kí tu alphabet')
    else:
        print(f'{c} không phải là kí tu alphabet')
else:
    print('Nhập lại')
# Out:
# Nhập lại

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
n=str(input())
c=ord(n)
if c in range(66,91):
    k=c-1
    print(chr(k).lower())
elif c==65:
    print(chr(122))

else:
    print('Nhập lại')
# Out:
# z

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a=float(input())
b=float(input())
c=float(input())
p=(a+b+c)/2
if a+b>c and a+c>b and b+c>a and c>0 and b>0 and c>0: 
    s=(p*(p-a)*(p-b)*(p-c))**0.5
    print(f'{s:.1f}')
else:
    print('Khong phai 3 canh cua tam giac')
# Out:
# 24.0

# %% [markdown]
# Phân loại tam giác cân, vuông, đều, thường

# %%
a=float(input())
b=float(input())
c=float(input())
p=(a+b+c)/2
if a+b>c and a+c>b and b+c>a and c>0 and b>0 and c>0:
    if a**2+b**2==c**2 or b**2+c**2==a**2 or a**2+c**2==b**2:
        print('tam giac vuong')
    elif a==b==c:
        print('tam giac deu')
    elif a==b or b==c or c==a:
        print('tam giac can') 
        if (a**2+b**2==c**2 and a==b) or (b**2+c**2==a**2 and b==c) or (a**2+c**2==b**2 and a==c):
            print('tam giac vuong can')
    else:
        print('tam giac thuong')

    s=(p*(p-a)*(p-b)*(p-c))**0.5
    print(f'{s:.1f}')
else:
    print('Khong phai 3 canh cua tam giac')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 a=float(input())
#       2 b=float(input())
# ----> 3 c=float(input())
#       4 p=(a+b+c)/2
#       5 if a+b>c and a+c>b and b+c>a and c>0 and b>0 and c>0:
#
# ValueError: could not convert string to float: '2**0.5'

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
a=str(input())
if len(a)<20:
    print('Nhập lại')
else:
    print(list(a)[5])
    print(list(a)[9])
# Out:
# g
# y

# %% [markdown]
# Bài 8:

# %%
a=str(input())
b=int(input())
c=int(input())
t=c-b
p=0
if t in range(0,50):
    p=t*1984
elif t in range(50,100):
    p=50*1984+(t-50)*2050
elif t in range(100,200):
    p=(t-100)*2380+50*1984+50*2050
elif t in range(200,300):
    p=(t-200)*2998+50*1984+50*2050+100*2380
elif t in range(300,400):
    p=(t-300)*3350+50*1984+50*2050+100*2380+100*2998
elif t>400:
    p=(t-400)*3460+1000*3350+100*2998+100*2380+50*2050+50*1984
print('Ho va ten',a)
print('Tiền phải trả là',f"{(p*1.08):.0f}")
# Out:
# Ho va ten h;hg;sghs
# Tiền phải trả là 100708
